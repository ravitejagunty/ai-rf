# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
housing_data = pd.read_csv('/week-3-practice-data-sets/Melbourne_Housing.csv')

# %%
housing_data
# Out:
#                  Suburb  Rooms Type        SellerG        Date  Distance  \
# 0          Airport West      3    t         Nelson  03-09-2016      13.5
# 1           Albert Park      2    h  hockingstuart  03-09-2016       3.3
# 2           Albert Park      2    h        Thomson  03-09-2016       3.3
# 3            Alphington      4    h          Brace  03-09-2016       6.4
# 4            Alphington      3    h         Jellis  03-09-2016       6.4
# ...                 ...    ...  ...            ...         ...       ...
# 27109        Noble Park      3    h            C21  30-09-2017      22.7
# 27110         Reservoir      3    u             RW  30-09-2017      12.0
# 27111     Roxburgh Park      4    h          Raine  30-09-2017      20.6
# 27112  Springvale South      3    h      Harcourts  30-09-2017      22.2
# 27113       Westmeadows      4    h          Barry  30-09-2017      16.5
#
#        Postcode  Bedroom  Bathroom  Car  Landsize BuildingArea  YearBuilt  \
# ...

# %%
housing_data.head()
# Out:
#          Suburb  Rooms Type        SellerG        Date  Distance  Postcode  \
# 0  Airport West      3    t         Nelson  03-09-2016      13.5    3042.0
# 1   Albert Park      2    h  hockingstuart  03-09-2016       3.3    3206.0
# 2   Albert Park      2    h        Thomson  03-09-2016       3.3    3206.0
# 3    Alphington      4    h          Brace  03-09-2016       6.4    3078.0
# 4    Alphington      3    h         Jellis  03-09-2016       6.4    3078.0
#
#    Bedroom  Bathroom  Car  Landsize BuildingArea  YearBuilt  \
# 0      3.0       2.0  1.0     303.0          225     2016.0
# 1      2.0       1.0  0.0     120.0           82     1900.0
# 2      2.0       1.0  0.0     159.0          inf        NaN
# 3      3.0       2.0  4.0     853.0          263     1930.0
# 4      3.0       2.0  2.0     208.0          inf     2013.0
#
#               Regionname  Propertycount    Price
# 0   Western Metropolitan           3464   840000
# 1  Southern Metropolitan           3280  1275000
# ...

# %%
housing_data.tail()
# Out:
#                  Suburb  Rooms Type    SellerG        Date  Distance  \
# 27109        Noble Park      3    h        C21  30-09-2017      22.7
# 27110         Reservoir      3    u         RW  30-09-2017      12.0
# 27111     Roxburgh Park      4    h      Raine  30-09-2017      20.6
# 27112  Springvale South      3    h  Harcourts  30-09-2017      22.2
# 27113       Westmeadows      4    h      Barry  30-09-2017      16.5
#
#        Postcode  Bedroom  Bathroom  Car  Landsize BuildingArea  YearBuilt  \
# 27109    3174.0      3.0       1.0  6.0     569.0          130     1959.0
# 27110    3073.0      3.0       1.0  1.0       NaN          105     1990.0
# 27111    3064.0      4.0       2.0  2.0       NaN          225     1995.0
# 27112    3172.0      3.0       2.0  1.0     544.0          NaN        NaN
# 27113    3049.0      4.0       2.0  6.0     813.0          140     1960.0
#
#                        Regionname  Propertycount   Price
# ...

# %%
housing_data.shape
# Out:
# (27114, 16)

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  object
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10543 non-null  object
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 3.3+ MB

# %%
housing_data['Date'] = pd.to_datetime(housing_data['Date'], dayfirst=True)

# %%
housing_data['BuildingArea'].unique()
# Out:
# array(['225', '82', 'inf', '263', '242', '251', '117', 'missing', '76',
#        '399', '118', '103', '180', '123', '218', '129', '167', '154',
#        '275', '121', nan, '125', '255', '75', '156', '240', '268', '108',
#        '69', '140', '214', '253', '189', '215', '96', '104', '100', '313',
#        '144', '93', '110', '70', '122', '51', '147', '113', '83', '56',
#        '137', '85', '64', '175', '3558', '170', '265', '353', '138', '19',
#        '116', '87', '74', '320', '300', '210', '120', '86', '97', '200',
#        '106', '14', '161', '128', '185', '146', '133', '115', '143',
#        '150', '195', '236', '276', '188', '179', '249', '141', '34', '73',
#        '107', '84', '81', '207', '50', '264', '312', '235', '221', '183',
#        '132', '160', '186', '78', '105', '145', '62', '220', '315', '181',
#        '61', '112', '420', '226', '266', '410', '449', '356', '477',
#        '250', '95', '190', '284', '247', '213', '209', '119', '111',
# ...

# %%
housing_data['BuildingArea'].apply(type).value_counts()
# Out:
# BuildingArea
# <class 'float'>    16571
# <class 'str'>      10543
# Name: count, dtype: int64

# %%
housing_data['BuildingArea'] = housing_data['BuildingArea'].replace(['missing','inf'],np.nan)

# %%
housing_data['BuildingArea'] = housing_data['BuildingArea'].astype(float)

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27114 entries, 0 to 27113
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27114 non-null  object
#  1   Rooms          27114 non-null  int64
#  2   Type           27114 non-null  object
#  3   SellerG        27114 non-null  object
#  4   Date           27114 non-null  datetime64[ns]
#  5   Distance       27113 non-null  float64
#  6   Postcode       27113 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27114 non-null  object
#  14  Propertycount  27114 non-null  int64
#  15  Price          27114 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(4)
# ...

# %%
housing_data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           6436
# Bathroom          6442
# Car               6817
# Landsize          9241
# BuildingArea     16585
# YearBuilt        15129
# Regionname           0
# Propertycount        0
# Price                0
# dtype: int64

# %%
housing_data.duplicated().sum()
# Out:
# 11

# %%
housing_data.drop_duplicates(inplace=True)

# %%
housing_data.reset_index(drop=True,inplace=True)

# %%
housing_data.duplicated().sum()
# Out:
# 0

# %%
housing_data.describe().T
# Out:
#                  count                           mean                  min  \
# Rooms          27103.0                       2.992473                  1.0
# Date             27103  2017-05-23 12:25:09.441759488  2016-01-28 00:00:00
# Distance       27102.0                      11.279931                  0.0
# Postcode       27102.0                    3113.787322               3000.0
# Bedroom        20678.0                       3.046184                  0.0
# Bathroom       20672.0                       1.591525                  0.0
# Car            20297.0                        1.71582                  0.0
# Landsize       17873.0                     560.536564                 50.0
# BuildingArea   10529.0                     154.511857                 11.0
# YearBuilt      11985.0                    1966.618273               1850.0
# Propertycount  27103.0                    7564.741025                 83.0
# ...

# %%
housing_data['Postcode'].nunique()
# Out:
# 209

# %%
cat_cols = ['Suburb','Type','SellerG','Regionname']

# %%
for column in cat_cols:
    print(housing_data[column].value_counts())
    print("-" * 50)
# Out:
# Suburb
# Reservoir         724
# Bentleigh East    493
# Richmond          437
# Preston           410
# Brunswick         383
#                  ...
# Wandin North        1
# Ferny Creek         1
# Tecoma              1
# Montrose            1
# viewbank            1
# Name: count, Length: 345, dtype: int64
# --------------------------------------------------
# Type
# h    18394
# u     5882
# t     2827
# Name: count, dtype: int64
# --------------------------------------------------
# SellerG
# Nelson           2733
# Jellis           2516
# Barry            2385
# hockingstuart    2096
# Ray              1574
#                  ...
# Allan               1
# Jim                 1
# iProperty           1
# Batty               1
# Icon                1
# Name: count, Length: 347, dtype: int64
# --------------------------------------------------
# Regionname
# Southern Metropolitan         8480
# Northern Metropolitan         7809
# Western Metropolitan          5792
# ...

# %%
for column in cat_cols:
    print(housing_data[column].value_counts(normalize=True))
    print("-" * 50)
# Out:
# Suburb
# Reservoir         0.026713
# Bentleigh East    0.018190
# Richmond          0.016124
# Preston           0.015127
# Brunswick         0.014131
#                     ...
# Wandin North      0.000037
# Ferny Creek       0.000037
# Tecoma            0.000037
# Montrose          0.000037
# viewbank          0.000037
# Name: proportion, Length: 345, dtype: float64
# --------------------------------------------------
# Type
# h    0.678670
# u    0.217024
# t    0.104306
# Name: proportion, dtype: float64
# --------------------------------------------------
# SellerG
# Nelson           0.100838
# Jellis           0.092831
# Barry            0.087998
# hockingstuart    0.077335
# Ray              0.058075
#                    ...
# Allan            0.000037
# Jim              0.000037
# iProperty        0.000037
# Batty            0.000037
# Icon             0.000037
# Name: proportion, Length: 347, dtype: float64
# --------------------------------------------------
# Regionname
# ...

# %%
housing_data[housing_data['Bedroom'] == 3.0]
housing_data['month'] = housing_data['Date'].dt.month
housing_data['day'] = housing_data['Date'].dt.day
housing_data['year'] = housing_data['Date'].dt.year
housing_data
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 0          Airport West      3    t         Nelson 2016-09-03      13.5
# 1           Albert Park      2    h  hockingstuart 2016-09-03       3.3
# 2           Albert Park      2    h        Thomson 2016-09-03       3.3
# 3            Alphington      4    h          Brace 2016-09-03       6.4
# 4            Alphington      3    h         Jellis 2016-09-03       6.4
# ...                 ...    ...  ...            ...        ...       ...
# 27098        Noble Park      3    h            C21 2017-09-30      22.7
# 27099         Reservoir      3    u             RW 2017-09-30      12.0
# 27100     Roxburgh Park      4    h          Raine 2017-09-30      20.6
# 27101  Springvale South      3    h      Harcourts 2017-09-30      22.2
# 27102       Westmeadows      4    h          Barry 2017-09-30      16.5
#
#        Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %%
sns.histplot(data=housing_data, x='Price',bins=50, kde=True);

# %%
sns.histplot(data=housing_data, x='Bathroom',bins=50, kde=True);

# %%
sns.histplot(data=housing_data, x='Distance',bins=50, kde=True);

# %%
sns.histplot(data=housing_data, x='Price',hue='Bedroom', kde=True);

# %%
sub_plots = sns.FacetGrid(housing_data, col='Bedroom')
sub_plots.map(sns.histplot, 'Price')

# %%
#plt.xlim(-1,20)
#plt.xlabel('Price')
#sns.axes_style('whitegrid')
plt.figure(figsize=(10,10))
sns.boxplot(data=housing_data, x='Bedroom', y='Price')
# Out:
# <Axes: xlabel='Bedroom', ylabel='Price'>

# %%
sns.histplot(data=housing_data, x='Price', kde=True);

# %%
sns.countplot(data=housing_data, x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
plt.figure(figsize=(20, 10))
sns.countplot(data=housing_data, x='Bedroom', hue='Price')
# Out:
# <Axes: xlabel='Bedroom', ylabel='count'>

# %%
plt.xlim(1,12)
sns.lineplot(data=housing_data, x='month', y='Rooms', ci=False, hue='year', markers=True)
# Out:
# /var/folders/zg/x79l7_nj6751wsbkqrbwqmz00000gn/T/ipykernel_33773/1217225161.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data=housing_data, x='month', y='Rooms', ci=False, hue='year', markers=True)
# <Axes: xlabel='month', ylabel='Rooms'>

# %%
sns.histplot(data=housing_data,x='Distance',stat='density')
plt.show()
sns.boxplot(data=housing_data,x='Distance')
plt.show()

# %%
sns.histplot(data=housing_data,x='Landsize',kde=True)
plt.show()
sns.boxplot(data=housing_data,x='Landsize')
plt.show()

# %%
# KDE plot
sns.kdeplot(data=housing_data, x='Landsize')
plt.title('KDE Plot of Landsize')
plt.show()

# %%
housing_data.loc[housing_data['Landsize'] > 60000]
# Out:
#              Suburb  Rooms Type    SellerG       Date  Distance  Postcode  \
# 23897        Silvan      3    h  Harcourts 2017-05-27      34.6    3795.0
# 25079  Balwyn North      3    h        Kay 2016-08-28       9.2    3104.0
#
#        Bedroom  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 23897      3.0       2.0  2.0   76000.0           NaN        NaN
# 25079      3.0       1.0  2.0   75100.0           NaN        NaN
#
#                   Regionname  Propertycount    Price  month  day  year
# 23897       Eastern Victoria            457  1085000      5   27  2017
# 25079  Southern Metropolitan           7809  2000000      8   28  2016

# %%
# KDE plot
sns.kdeplot(data=housing_data, x='BuildingArea')
plt.title('KDE Plot of Building area')
plt.show()
sns.boxplot(data=housing_data, x='BuildingArea')
plt.show()

# %%
# hist, KDE, box plot
sns.histplot(data=housing_data, x='Price')
plt.title('Hist Plot of Price')
plt.show()
sns.kdeplot(data=housing_data, x='Price')
plt.title('KDE Plot of Price')
plt.show()
sns.boxplot(data=housing_data, x='Price')
plt.show()

# %%
sns.countplot(data=housing_data, x='Regionname')
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(data=housing_data, x='Distance', y='Price', hue='BuildingArea')
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27103 entries, 0 to 27102
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27103 non-null  object
#  1   Rooms          27103 non-null  int64
#  2   Type           27103 non-null  object
#  3   SellerG        27103 non-null  object
#  4   Date           27103 non-null  datetime64[ns]
#  5   Distance       27102 non-null  float64
#  6   Postcode       27102 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27103 non-null  object
#  14  Propertycount  27103 non-null  int64
#  15  Price          27103 non-null  int64
#  16  month          27103 non-null  int32
# ...

# %%
sns.pairplot(data=housing_data[['Rooms','Distance','Landsize','BuildingArea','year','Price']])

# %%
sns.heatmap(data=housing_data[['Rooms','Distance','Landsize','BuildingArea','year','Price']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(data=housing_data[['Rooms','Distance','Landsize','BuildingArea','year','Price']].corr(), annot=True, cbar=False)
# Out:
# <Axes: >

# %%
# plt.figure(figsize=(10,5))
# sns.heatmap(housing_data.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
# plt.show()
# housing_data.corr()

# %%
numeric_data = housing_data.select_dtypes(include=[np.number])

# %%
numeric_data
# Out:
#        Rooms  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  \
# 0          3      13.5    3042.0      3.0       2.0  1.0     303.0
# 1          2       3.3    3206.0      2.0       1.0  0.0     120.0
# 2          2       3.3    3206.0      2.0       1.0  0.0     159.0
# 3          4       6.4    3078.0      3.0       2.0  4.0     853.0
# 4          3       6.4    3078.0      3.0       2.0  2.0     208.0
# ...      ...       ...       ...      ...       ...  ...       ...
# 27098      3      22.7    3174.0      3.0       1.0  6.0     569.0
# 27099      3      12.0    3073.0      3.0       1.0  1.0       NaN
# 27100      4      20.6    3064.0      4.0       2.0  2.0       NaN
# 27101      3      22.2    3172.0      3.0       2.0  1.0     544.0
# 27102      4      16.5    3049.0      4.0       2.0  6.0     813.0
#
#        BuildingArea  YearBuilt  Propertycount    Price  month  day  year
# 0             225.0     2016.0           3464   840000      9    3  2016
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(numeric_data.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
plt.show()

# %%
numeric_data.corr()
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.284292  0.081118  0.958584  0.608516  0.394298
# Distance       0.284292  1.000000  0.490217  0.282802  0.140484  0.244562
# Postcode       0.081118  0.490217  1.000000  0.087373  0.123812  0.062646
# Bedroom        0.958584  0.282802  0.087373  1.000000  0.605910  0.395814
# Bathroom       0.608516  0.140484  0.123812  0.605910  1.000000  0.306358
# Car            0.394298  0.244562  0.062646  0.395814  0.306358  1.000000
# Landsize       0.071494  0.118486  0.076461  0.071124  0.055461  0.091536
# BuildingArea   0.418217  0.101988  0.060371  0.412782  0.388836  0.217719
# YearBuilt     -0.003780  0.320887  0.100183  0.006388  0.186618  0.133013
# Propertycount -0.079686 -0.021224  0.024291 -0.059713 -0.040498 -0.013524
# Price          0.465160 -0.211194  0.045016  0.430031  0.430852  0.201333
# month          0.013973  0.010557  0.009105  0.017581  0.017615  0.017551
# ...

# %%
housing_data['Distance_bins']=pd.cut(numeric_data['Distance'], bins=[0,15,30,50], labels=['Near By', 'Moderately Close', 'Far'], right=False)

# %%
housing_data
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 0          Airport West      3    t         Nelson 2016-09-03      13.5
# 1           Albert Park      2    h  hockingstuart 2016-09-03       3.3
# 2           Albert Park      2    h        Thomson 2016-09-03       3.3
# 3            Alphington      4    h          Brace 2016-09-03       6.4
# 4            Alphington      3    h         Jellis 2016-09-03       6.4
# ...                 ...    ...  ...            ...        ...       ...
# 27098        Noble Park      3    h            C21 2017-09-30      22.7
# 27099         Reservoir      3    u             RW 2017-09-30      12.0
# 27100     Roxburgh Park      4    h          Raine 2017-09-30      20.6
# 27101  Springvale South      3    h      Harcourts 2017-09-30      22.2
# 27102       Westmeadows      4    h          Barry 2017-09-30      16.5
#
#        Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %%
numeric_data.corr()
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.284292  0.081118  0.958584  0.608516  0.394298
# Distance       0.284292  1.000000  0.490217  0.282802  0.140484  0.244562
# Postcode       0.081118  0.490217  1.000000  0.087373  0.123812  0.062646
# Bedroom        0.958584  0.282802  0.087373  1.000000  0.605910  0.395814
# Bathroom       0.608516  0.140484  0.123812  0.605910  1.000000  0.306358
# Car            0.394298  0.244562  0.062646  0.395814  0.306358  1.000000
# Landsize       0.071494  0.118486  0.076461  0.071124  0.055461  0.091536
# BuildingArea   0.418217  0.101988  0.060371  0.412782  0.388836  0.217719
# YearBuilt     -0.003780  0.320887  0.100183  0.006388  0.186618  0.133013
# Propertycount -0.079686 -0.021224  0.024291 -0.059713 -0.040498 -0.013524
# Price          0.465160 -0.211194  0.045016  0.430031  0.430852  0.201333
# month          0.013973  0.010557  0.009105  0.017581  0.017615  0.017551
# ...

# %%
housing_data
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 0          Airport West      3    t         Nelson 2016-09-03      13.5
# 1           Albert Park      2    h  hockingstuart 2016-09-03       3.3
# 2           Albert Park      2    h        Thomson 2016-09-03       3.3
# 3            Alphington      4    h          Brace 2016-09-03       6.4
# 4            Alphington      3    h         Jellis 2016-09-03       6.4
# ...                 ...    ...  ...            ...        ...       ...
# 27098        Noble Park      3    h            C21 2017-09-30      22.7
# 27099         Reservoir      3    u             RW 2017-09-30      12.0
# 27100     Roxburgh Park      4    h          Raine 2017-09-30      20.6
# 27101  Springvale South      3    h      Harcourts 2017-09-30      22.2
# 27102       Westmeadows      4    h          Barry 2017-09-30      16.5
#
#        Postcode  Bedroom  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# ...

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27103 entries, 0 to 27102
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27103 non-null  object
#  1   Rooms          27103 non-null  int64
#  2   Type           27103 non-null  object
#  3   SellerG        27103 non-null  object
#  4   Date           27103 non-null  datetime64[ns]
#  5   Distance       27102 non-null  float64
#  6   Postcode       27102 non-null  float64
#  7   Bedroom        20678 non-null  float64
#  8   Bathroom       20672 non-null  float64
#  9   Car            20297 non-null  float64
#  10  Landsize       17873 non-null  float64
#  11  BuildingArea   10529 non-null  float64
#  12  YearBuilt      11985 non-null  float64
#  13  Regionname     27103 non-null  object
#  14  Propertycount  27103 non-null  int64
#  15  Price          27103 non-null  int64
#  16  month          27103 non-null  int32
# ...

# %%
housing_data['AgeOfProp']=housing_data['year']-housing_data['YearBuilt']

# %%
housing_data
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 0          Airport West      3    t         Nelson 2016-09-03      13.5
# 1           Albert Park      2    h  hockingstuart 2016-09-03       3.3
# 2           Albert Park      2    h        Thomson 2016-09-03       3.3
# 3            Alphington      4    h          Brace 2016-09-03       6.4
# 4            Alphington      3    h         Jellis 2016-09-03       6.4
# ...                 ...    ...  ...            ...        ...       ...
# 27098        Noble Park      3    h            C21 2017-09-30      22.7
# 27099         Reservoir      3    u             RW 2017-09-30      12.0
# 27100     Roxburgh Park      4    h          Raine 2017-09-30      20.6
# 27101  Springvale South      3    h      Harcourts 2017-09-30      22.2
# 27102       Westmeadows      4    h          Barry 2017-09-30      16.5
#
#        Postcode  Bedroom  Bathroom  Car  ...  BuildingArea  YearBuilt  \
# ...

# %%
housing_data[housing_data['AgeOfProp'] < 0]
# Out:
#                  Suburb  Rooms Type   SellerG       Date  Distance  Postcode  \
# 285    Avondale Heights      3    t    Nelson 2016-12-03      10.5    3034.0
# 13854         Bentleigh      3    h  Woodards 2018-03-17      11.4    3204.0
# 15232         Reservoir      4    h     Barry 2016-09-17      11.2    3073.0
# 19463       Keilor East      3    h    Nelson 2016-04-23      12.8    3033.0
# 21326     Brighton East      2    h    Buxton 2016-09-24      10.7    3187.0
# 24897           Newport      3    h       Jas 2016-05-28       8.4    3015.0
# 27069        Heidelberg      3    h     Miles 2016-07-30      10.6    3084.0
#
#        Bedroom  Bathroom  Car  ...  BuildingArea  YearBuilt  \
# 285        3.0       3.0  1.0  ...         181.0     2017.0
# 13854      3.0       1.0  4.0  ...         242.0     2019.0
# 15232      3.0       2.0  2.0  ...         129.0     2017.0
# 19463      3.0       2.0  1.0  ...         126.0     2017.0
# ...

# %%
sns.lineplot(data=housing_data, x='AgeOfProp', y='Price',errorbar=None)
# Out:
# <Axes: xlabel='AgeOfProp', ylabel='Price'>

# %%
sns.relplot(data=housing_data,x='AgeOfProp',y='Price',col='Regionname',kind='line',errorbar=None, col_wrap=4)

# %%
sns.boxplot(data=housing_data, x='Regionname', y='Price', showfliers=False)
plt.xticks(rotation=90);

# %%
np.max(housing_data['year'])
# Out:
# 2018

# %%
housing_data
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 0          Airport West      3    t         Nelson 2016-09-03      13.5
# 1           Albert Park      2    h  hockingstuart 2016-09-03       3.3
# 2           Albert Park      2    h        Thomson 2016-09-03       3.3
# 3            Alphington      4    h          Brace 2016-09-03       6.4
# 4            Alphington      3    h         Jellis 2016-09-03       6.4
# ...                 ...    ...  ...            ...        ...       ...
# 27098        Noble Park      3    h            C21 2017-09-30      22.7
# 27099         Reservoir      3    u             RW 2017-09-30      12.0
# 27100     Roxburgh Park      4    h          Raine 2017-09-30      20.6
# 27101  Springvale South      3    h      Harcourts 2017-09-30      22.2
# 27102       Westmeadows      4    h          Barry 2017-09-30      16.5
#
#        Postcode  Bedroom  Bathroom  Car  ...  BuildingArea  YearBuilt  \
# ...

# %%
housing_data.loc[housing_data['Distance'].isnull()==True]
# Out:
#            Suburb  Rooms Type SellerG       Date  Distance  Postcode  Bedroom  \
# 9590  Fawkner Lot      3    h    Brad 2018-01-06       NaN       NaN      NaN
#
#       Bathroom  Car  ...  BuildingArea  YearBuilt             Regionname  \
# 9590       NaN  NaN  ...           NaN        NaN  Northern Metropolitan
#
#      Propertycount   Price  month  day  year  Distance_bins AgeOfProp
# 9590           962  616000      1    6  2018            NaN       NaN
#
# [1 rows x 21 columns]

# %%
housing_data.loc[housing_data['Suburb']=='Fawkner Lot']
# Out:
#            Suburb  Rooms Type SellerG       Date  Distance  Postcode  Bedroom  \
# 9590  Fawkner Lot      3    h    Brad 2018-01-06       NaN       NaN      NaN
#
#       Bathroom  Car  ...  BuildingArea  YearBuilt             Regionname  \
# 9590       NaN  NaN  ...           NaN        NaN  Northern Metropolitan
#
#      Propertycount   Price  month  day  year  Distance_bins AgeOfProp
# 9590           962  616000      1    6  2018            NaN       NaN
#
# [1 rows x 21 columns]

# %%
housing_data = housing_data.drop(9590).reset_index(drop=True)

# %%
pd.DataFrame({'Count':housing_data.isnull().sum()[housing_data.isnull().sum()>0],'Percentage':(housing_data.isnull().sum()[housing_data.isnull().sum()>0]/housing_data.shape[0])*100})
# Out:
#               Count  Percentage
# Bedroom        6424   23.703048
# Bathroom       6430   23.725186
# Car            6805   25.108848
# Landsize       9229   34.052837
# BuildingArea  16573   61.150469
# YearBuilt     15117   55.778171
# AgeOfProp     15117   55.778171

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True]
# Out:
#                  Suburb  Rooms Type        SellerG       Date  Distance  \
# 8          Altona North      4    h  hockingstuart 2016-09-03      11.1
# 12            Ashburton      2    h       Marshall 2016-09-03      11.0
# 14     Avondale Heights      4    h         Jellis 2016-09-03      10.5
# 25         Balwyn North      4    u  hockingstuart 2016-09-03       9.2
# 26         Balwyn North      2    h      Fletchers 2016-09-03       9.2
# ...                 ...    ...  ...            ...        ...       ...
# 27088         Footscray      2    u        McGrath 2017-09-30       5.1
# 27089       Forest Hill      2    h      Fletchers 2017-09-30      15.4
# 27090     Glen Waverley      3    u            Ray 2017-09-30      16.7
# 27093         Kingsbury      2    t             RW 2017-09-30      12.1
# 27095           Mitcham      4    h           Noel 2017-09-30      17.2
#
#        Postcode  Bedroom  Bathroom  Car  ...  BuildingArea  YearBuilt  \
# ...

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'Bathroom'].value_counts(dropna=False)
# Out:
# Bathroom
# NaN    6424
# Name: count, dtype: int64

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'Car'].value_counts(dropna=False)
# Out:
# Car
# NaN    6424
# Name: count, dtype: int64

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'Landsize'].value_counts(dropna=False)
# Out:
# Landsize
# NaN      6418
# 594.0       1
# 446.0       1
# 338.0       1
# 250.0       1
# 549.0       1
# 239.0       1
# Name: count, dtype: int64

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'BuildingArea'].value_counts(dropna=False)
# Out:
# BuildingArea
# NaN    6424
# Name: count, dtype: int64

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'YearBuilt'].value_counts(dropna=False)
# Out:
# YearBuilt
# NaN    6424
# Name: count, dtype: int64

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'Suburb'].value_counts(dropna=False)
# Out:
# Suburb
# Reservoir          236
# Bentleigh East     144
# St Kilda           116
# Glenroy            116
# Richmond           111
#                   ...
# Cranbourne East      1
# Melton West          1
# New Gisborne         1
# Scoresby             1
# Plenty               1
# Name: count, Length: 307, dtype: int64

# %%
housing_data.loc[housing_data['Bedroom'].isnull()==True, 'Regionname'].value_counts(dropna=False)
# Out:
# Regionname
# Southern Metropolitan         2197
# Northern Metropolitan         1912
# Western Metropolitan          1212
# Eastern Metropolitan           728
# South-Eastern Metropolitan     317
# Eastern Victoria                26
# Northern Victoria               25
# Western Victoria                 7
# Name: count, dtype: int64
